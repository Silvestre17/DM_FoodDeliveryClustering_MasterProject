# %%
import pandas as pd

file = r'C:\Users\Utilizador\Desktop\NOVA IMS\1º semestre\Data Mining\projeto\DM2425_ABCDEats_DATASET.csv'
df = pd.read_csv(file)

pd.set_option('display.max_rows', None)  # Mostrar todas as linhas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 file = r'C:\Users\Utilizador\Desktop\NOVA IMS\1º semestre\Data Mining\projeto\DM2425_ABCDEats_DATASET.csv'
# ----> 4 df = pd.read_csv(file)
#       6 pd.set_option('display.max_rows', None)
#
# ...

# %% [markdown]
# Na variável order_count posso estar a cometer um erro em 4%
# Resumo estatístico da variável 'order_count':
# count__    31888.000000
# mean__         4.368822
# std__          5.084469
# min__          0.000000
# 25%__          2.000000
# 50%__          3.000000
# 75%__          5.000000
# max__         94.000000

# %%
#Criar 'order_count'= somatório das colunas dow_0 a dow_6
df['order_count'] = df[[f'DOW_{i}' for i in range(7)]].sum(axis=1)

#Criar 'price_per_order' dividindo a soma das colunas CUI_* pelo 'order_count'
culinarias = ['CUI_American', 'CUI_Asian', 'CUI_Beverages', 'CUI_Cafe', 
              'CUI_Chicken Dishes', 'CUI_Chinese', 'CUI_Desserts', 
              'CUI_Healthy', 'CUI_Indian', 'CUI_Italian', 'CUI_Japanese', 
              'CUI_Noodle Dishes', 'CUI_OTHER', 'CUI_Street Food / Snacks', 
              'CUI_Thai']

# Somar o gasto total em culinária e dividir pelo número de pedidos ('order_count')
df['price_per_order'] = df[culinarias].sum(axis=1) / df['order_count']

# Filtrar o DataFrame para remover linhas onde order_count é 0
df_filtered = df[df['order_count'] > 0].copy()

# Calcular quantas observações foram perdidas
observacoes_perdidas = len(df) - len(df_filtered)

# Exibir os resultados
print(f"Número total de observações: {len(df)}")
print(f"Número de observações após filtro: {len(df_filtered)}")
print(f"Número de observações perdidas: {observacoes_perdidas}")
# Out:
# Número total de observações: 31888
# Número de observações após filtro: 31750
# Número de observações perdidas: 138

# %% [markdown]
# -------------------------------------------------------------------------------------------------- IDEIAS --------------------------------------------------------------------------------------------------
# - A média e mediana de idades total é igual à média e mediana de idades de clientes que pediram em mais do que 5 chains (iguais ou não); o mesmo acontece com as regiões; gastos médios por tipo de cozinha já é diferente
#
# relacionar is_chain com o gasto total, com a quantidade de produtos pedidos, ou até com a frequência de pedidos
#
#
# calcular o percentual de pedidos feitos em chains versus não-chains em cada horário. Isso ajudaria a identificar se o comportamento é realmente direcionado às chains ou se é reflexo do volume total de pedidos.
#
# Tentar ver se à medida que o nr de prod aumenta tb aumenta a proporção de pedidos em chain? mas como média de prod. por pedido
# ???Qual a proporção média do nr de pedidos em chains/nr de pedidos---> como arranjo nr pedidos
# podem ter sido mandadas vir da mesma chain ou não
# certos sítios ou idades ser freq
# Proporção entre chain e restaurantes independentes.Gráfico de barras ou gráfico de pizza
# Estará correlacionado com:
# Gasto total: Os clientes que preferem chains gastam mais ou menos em média?
# Tipos de culinária: Existe uma diferença nos tipos de culinária preferidos entre quem pede de chains e independentes?
# Frequência de pedidos: Clientes que preferem chains fazem pedidos com mais ou menos frequência?

# %% [markdown]
# # is_chain

# %% [markdown]
# Esta variável toma valores entre 0 e 83 e não tem missings (31888 obs)
#
# Durante os 3 meses foi mais frequente os consumidores mandarem vir de 1,0,2,3...chains pois:
#
# Mais de 50% (precisamente 64,43%) dos consumidores mandaram vir entre [0,2] pedidos de chains
#
# Mais de 75% (precisamente 76,02%) dos consumidores mandaram vir entre [0,3] pedidos de chains
# Os pedidos em chains costuma ser mais de forma pontual
#
# (+ estatística)
# Assimetria: 4.99 dist. assimétrica à direita(+). A maioria dos clientes faz poucos pedidos em chains e um pequeno número de clientes faz muitos pedidos.
# Média: 2.818866031108881 que está de acordo com a assimetria
# Mediana: 2.0

# %%
#1.
# Freq relativa
rel_values = df['is_chain'].value_counts(normalize=True)
print("Frequências relativas:")
print(rel_values * 100)

#Haverá outliers?
print("\nResumo estatístico da variável 'is_chain':")
print(df['is_chain'].describe())

# Boxplot
"""
import matplotlib.pyplot as plt
plt.boxplot(df['is_chain'])
plt.title("Boxplot de 'is_chain'")
plt.show()
"""
# Out:
# Frequências relativas:
# 1     26.803186
# 0     19.141997
# 2     18.480306
# 3     11.596839
# 4      6.789388
# 5      4.327647
# 6      2.966633
# 7      2.129328
# 8      1.567988
# 9      1.172855
# 10     0.912569
# 11     0.777722
# 12     0.529980
# 13     0.476668
# 14     0.432765
# 15     0.279102
# 16     0.213246
# 18     0.203838
# 17     0.172479
# 19     0.109759
# 20     0.106623
# 21     0.090943
# 22     0.081535
# 24     0.072127
# 23     0.062720
# 26     0.062720
# 27     0.050176
# 25     0.043904
# 28     0.040768
# 29     0.031360
# 31     0.028224
# 30     0.028224
# 32     0.025088
# 33     0.018816
# 34     0.018816
# 36     0.015680
# 43     0.015680
# 40     0.015680
# 37     0.012544
# 35     0.012544
# 45     0.012544
# 39     0.006272
# 42     0.006272
# 48     0.006272
# 75     0.003136
# 63     0.003136
# 54     0.003136
# 83     0.003136
# 49     0.003136
# 46     0.003136
# 61     0.003136
# 44     0.003136
# 67     0.003136
# 56     0.003136
# ...

# %% [markdown]
# Independentemente da intensidade, a correlação da variável is_chain com as demais é positiva com exceção da variável first_order: quanto mais tarde foi feito o 1º pedido menos quantidades de pedidos vindos de chains foram feitos ao longo dos 3 meses. É natural porque fizeram poucos pedidos quer chain quer não
#
# corr com product_count e vendor_count não diz muito
# Um valor alto de product_count indica que o cliente fez muitos "pedidos", o que geralmente implica um maior número de pedidos em chains, mas também pode implicar um maior número de pedidos em restaurantes independentes. A mesma lógica aplica-se a vendor_count: mais fornecedores indicam maior variedade de pedidos, mas isso não necessariamente significa que todos são de chains. É importante considerar que um cliente pode ser mais propenso a experimentar diferentes restaurantes, independentemente de serem chains ou independentes.
#
# DOW (Day of the Week)
# As altas correlações com DOW também não dizem nada
#
#
# As var HR_... indicam um maior pedidos de restaurantes chains às 11, 12, 18, 19, 13 e 17, não quer dizer que a percentagem de pedidos em restaurantes chain aumente sequer, é importante considerar que podem ser momentos de alta procura de pedidos em geral, o que inclui tanto chains quanto restaurantes independentes. As horas mais comuns são 17, 11, 16, 18, 10, 12
#
#
# CUI_Chicken Dishes e noodles talvez seja o tipo de restaurante onde é mais comum mandar vir chain
# CUI_Asian,CUI_American CUI_Street Food / Snacks,CUI_Italian,CUI_OTHER,CUI_Japanese, CUI_Beverages, CUI_Indian

# %%
"""
#2.
#Matriz de correlação
corr_matrix = df.corr()
# Exibir apenas a correlação de 'is_chain' com as outras variáveis
is_chain_correlation = corr_matrix['is_chain'].sort_values(ascending=False)
print(is_chain_correlation)
"""
# Out:
# "\n#2.\n#Matriz de correlação\ncorr_matrix = df.corr()\n# Exibir apenas a correlação de 'is_chain' com as outras variáveis\nis_chain_correlation = corr_matrix['is_chain'].sort_values(ascending=False)\nprint(is_chain_correlation)\n"

# %% [markdown]
# !!!!!!!!!ESTUDAR SOBRE NR ORDERS=0!!!!!!!

# %% [markdown]
# ### customer_age

# %%
# Calcular a percentagem de pedidos em chains para cada consumidor
df_filtered.loc[:, 'percent_chain'] = df_filtered['is_chain'] / df_filtered['order_count']  # Usar .loc

# Ordenar os consumidores pela percentagem de pedidos em chains em ordem decrescente
top_consumidores_chain = df_filtered.sort_values(by='percent_chain', ascending=False).head(29595)  # 1595 Ajuste o número conforme necessário

# Exibir os resultados
print(top_consumidores_chain[['customer_id', 'percent_chain']])
# Out:
#       customer_id  percent_chain
# 15910  adcfa1c60d       1.000000
# 24875  68ef6f0270       1.000000
# 24882  74d4da2728       1.000000
# 12117  3f038ae05d       1.000000
# 12119  6d90031879       1.000000
# 12120  8ba787555d       1.000000
# 24879  6ee234bf9d       1.000000
# 24878  6da7e9696a       1.000000
# 12123  acb112560c       1.000000
# 12125  d0ff2ab67e       1.000000
# 24877  6c1b517eb8       1.000000
# 24876  6bd579109f       1.000000
# 12133  3c845bffaa       1.000000
# 12134  41b4e74eeb       1.000000
# 12136  4f3998584c       1.000000
# 24873  61ed24c864       1.000000
# 25019  d1502354d7       1.000000
# 24872  60238e2741       1.000000
# 12140  8525ab8427       1.000000
# 24871  56bcda704e       1.000000
# 12142  8c6c8fb705       1.000000
# 24870  4fea3dc59d       1.000000
# 24868  4d90660957       1.000000
# 24867  4cdb47a3bd       1.000000
# 12152  c7e074401c       1.000000
# 12153  d8b2a6535b       1.000000
# 12154  d94bfedec8       1.000000
# ...

# %%
"""
# Caracterizar a idade dos consumidores em df_filtered
idade_media = df_filtered['customer_age'].mean()
idade_minima = df_filtered['customer_age'].min()
idade_maxima = df_filtered['customer_age'].max()
distribuicao_idade = df_filtered['customer_age'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição de idades:")
print(distribuicao_idade)

print(f"\nIdade média: {idade_media:.2f}")
print(f"Idade mínima: {idade_minima}")
print(f"Idade máxima: {idade_maxima}")

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""
# Out:
# '\n# Caracterizar a idade dos consumidores em df_filtered\nidade_media = df_filtered[\'customer_age\'].mean()\nidade_minima = df_filtered[\'customer_age\'].min()\nidade_maxima = df_filtered[\'customer_age\'].max()\ndistribuicao_idade = df_filtered[\'customer_age\'].value_counts().sort_index()\n\n# Exibir os resultados\nprint("Distribuição de idades:")\nprint(distribuicao_idade)\n\nprint(f"\nIdade média: {idade_media:.2f}")\nprint(f"Idade mínima: {idade_minima}")\nprint(f"Idade máxima: {idade_maxima}")\n\n# Exibir número total de observações\nprint(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")\n'

# %% [markdown]
# Dos 12778 consumidores que caem no filtro (percent_chain = 1), mais de 6000 (47.4%) tem idades entre os 21 e os 27
# Idade média: 27.45
# Idade mínima: 15.0
# Idade máxima: 77.0
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5), mais de 13661 (62.1%) tem idades entre os 20 e os 29
# Idade média: 27.49
# Idade mínima: 15.0
# Idade máxima: 80.0
# Mas isto já ocorre df_filtered (31750 obs) (aprox. 48% entre os 21 aos 27 e 62% entre os 20 aos 29)

# %%
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Calcular quantas observações foram filtradas
observacoes_filtradas = len(df_filtered) - len(consumidores_chain_1)

# Caracterizar a idade dos consumidores com percent_chain = 1
idade_media = consumidores_chain_1['customer_age'].mean()
idade_minima = consumidores_chain_1['customer_age'].min()
idade_maxima = consumidores_chain_1['customer_age'].max()
distribuicao_idade = consumidores_chain_1['customer_age'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição de idades:")
print(distribuicao_idade)
print(f"\nIdade média: {idade_media:.2f}")
print(f"Idade mínima: {idade_minima}")
print(f"Idade máxima: {idade_maxima}")
# Exibir número de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {observacoes_filtradas}")
# Out:
# Distribuição de idades:
# 15.0      9
# 16.0     29
# 17.0    117
# 18.0    241
# 19.0    450
# 20.0    595
# 21.0    816
# 22.0    940
# 23.0    895
# 24.0    907
# 25.0    878
# 26.0    824
# 27.0    800
# 28.0    645
# 29.0    601
# 30.0    533
# 31.0    443
# 32.0    403
# 33.0    321
# 34.0    294
# 35.0    266
# 36.0    197
# 37.0    167
# 38.0    161
# 39.0    145
# 40.0    117
# 41.0    104
# 42.0     95
# 43.0     73
# 44.0     45
# 45.0     46
# 46.0     53
# 47.0     33
# 48.0     30
# 49.0     28
# 50.0     28
# 51.0     31
# 52.0     17
# 53.0     22
# 54.0      9
# 55.0      8
# 56.0     10
# 57.0      9
# 58.0      8
# 59.0      4
# 60.0      4
# 61.0      3
# 62.0      4
# 63.0      5
# 65.0      2
# 66.0      3
# 67.0      1
# 68.0      6
# 70.0      2
# 72.0      1
# 74.0      1
# 75.0      1
# 76.0      2
# 77.0      3
# Name: customer_age, dtype: int64
#
# Idade média: 27.45
# Idade mínima: 15.0
# Idade máxima: 77.0
#
# ...

# %%
# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Calcular quantas observações foram filtradas
observacoes_filtradas = len(df_filtered) - len(consumidores_chain_05)

# Caracterizar a idade dos consumidores com percent_chain >= 0.5
idade_media = consumidores_chain_05['customer_age'].mean()
idade_minima = consumidores_chain_05['customer_age'].min()
idade_maxima = consumidores_chain_05['customer_age'].max()
distribuicao_idade = consumidores_chain_05['customer_age'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição de idades:")
print(distribuicao_idade)
print(f"\nIdade média: {idade_media:.2f}")
print(f"Idade mínima: {idade_minima}")
print(f"Idade máxima: {idade_maxima}")

# Exibir número de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {observacoes_filtradas}")
# Out:
# Distribuição de idades:
# 15.0      13
# 16.0      54
# 17.0     181
# 18.0     401
# 19.0     751
# 20.0    1014
# 21.0    1392
# 22.0    1583
# 23.0    1586
# 24.0    1583
# 25.0    1579
# 26.0    1424
# 27.0    1326
# 28.0    1120
# 29.0    1054
# 30.0     888
# 31.0     758
# 32.0     683
# 33.0     584
# 34.0     501
# 35.0     435
# 36.0     339
# 37.0     294
# 38.0     271
# 39.0     238
# 40.0     214
# 41.0     179
# 42.0     151
# 43.0     142
# 44.0     100
# 45.0      87
# 46.0      86
# 47.0      56
# 48.0      56
# 49.0      46
# 50.0      44
# 51.0      43
# 52.0      34
# 53.0      29
# 54.0      24
# 55.0      21
# 56.0      14
# 57.0      16
# 58.0      16
# 59.0       9
# 60.0       9
# 61.0       4
# 62.0       5
# 63.0       5
# 65.0       4
# 66.0       3
# 67.0       2
# 68.0       6
# 69.0       1
# 70.0       2
# 71.0       1
# 72.0       2
# 74.0       3
# 75.0       1
# 76.0       2
# 77.0       5
# 78.0       1
# 79.0       1
# 80.0       3
# ...

# %% [markdown]
# ### customer_region

# %% [markdown]
# Dos 12778 consumidores que caem no filtro (percent_chain = 1), mais de 11119 (87%) são das regiões: 2360, 4660, 8670
# 46.2% só da região 2360
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5), mais de 19405 (88.2%) são das regiões: 2360, 4660, 8670
# 37.4% só da região 2360
# Mas isto já ocorre df_filtered (31750 obs)
#
# | Segmento                                |        8670      |      4660      |     2360     |
# |-----------------------------------------|------------------|----------------|--------------|
# | Consumidores c/ `order_count` > 0        | 30.3             | 30.1           | 27.8         |
# | "  " & `percent_chain` == 1              | 21.2             | 19.7           | 46.2         |
# |"  " &  `percent_chain` >= 0.5            | 26.3             | 24.5           | 37.4         |

# %%
"""
# Caracterizar a distribuição dos consumidores em df_filtered por customer_region
distribuicao_regiao = df_filtered['customer_region'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição por regiões:")
print(distribuicao_regiao)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_1 = len(df_filtered) - len(consumidores_chain_1)

# Caracterizar a distribuição dos consumidores com percent_chain = 1 por customer_region
distribuicao_regiao_chain_1 = consumidores_chain_1['customer_region'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por regiões (percent_chain = 1):")
print(distribuicao_regiao_chain_1)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_1}")
"""

# %%
"""
# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_05 = len(df_filtered) - len(consumidores_chain_05)

# Caracterizar a distribuição dos consumidores com percent_chain >= 0.5 por customer_region
distribuicao_regiao_chain_05 = consumidores_chain_05['customer_region'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por regiões (percent_chain >= 0.5):")
print(distribuicao_regiao_chain_05)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_05}")
"""

# %% [markdown]
# ### vendor_count

# %% [markdown]
# df_filtered (31750 obs)
# Vendor count médio: 3.12
# Vendor count mínimo: 1
# Vendor count máximo: 41
#
# Dos 12778 consumidores que caem no filtro (percent_chain = 1), 84.3%  têm vendor_count entre 1 a 3
# Vendor count médio: 2.29
# Vendor count mínimo: 1
# Vendor count máximo: 30
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5), 86% têm vendor_count entre 1 a 5
# Vendor count médio: 3.27
# Vendor count mínimo: 1
# Vendor count máximo: 41
#
#
#
# | Segmento                                |        1      |      2      |     3     |
# |-----------------------------------------|------------------|----------------|--------------|
# | Consumidores c/ `order_count` > 0        | 28.5             | 26.9           | 16.3         |
# | "  " & `percent_chain` == 1              | 41.1             | 28.9           | 14.3         |
# |"  " &  `percent_chain` >= 0.5            | 23.9             | 29.5           | 16.3         |

# %%
"""
# Caracterizar o número de fornecedores (vendor_count) dos consumidores em df_filtered
vendor_count_media = df_filtered['vendor_count'].mean()
vendor_count_minima = df_filtered['vendor_count'].min()
vendor_count_maxima = df_filtered['vendor_count'].max()
distribuicao_vendor_count = df_filtered['vendor_count'].value_counts().sort_index()

# Exibir os resultados gerais
print("Distribuição de vendor_count:")
print(distribuicao_vendor_count)

print(f"\nVendor count médio: {vendor_count_media:.2f}")
print(f"Vendor count mínimo: {vendor_count_minima}")
print(f"Vendor count máximo: {vendor_count_maxima}")

# Exibir número total de observações em df_filtered
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Caracterizar vendor_count dos consumidores com percent_chain = 1
vendor_count_media_chain_1 = consumidores_chain_1['vendor_count'].mean()
vendor_count_minima_chain_1 = consumidores_chain_1['vendor_count'].min()
vendor_count_maxima_chain_1 = consumidores_chain_1['vendor_count'].max()
distribuicao_vendor_count_chain_1 = consumidores_chain_1['vendor_count'].value_counts().sort_index()

# Exibir os resultados para percent_chain = 1
print("\nDistribuição de vendor_count para percent_chain = 1:")
print(distribuicao_vendor_count_chain_1)
print(f"\nVendor count médio: {vendor_count_media_chain_1:.2f}")
print(f"Vendor count mínimo: {vendor_count_minima_chain_1}")
print(f"Vendor count máximo: {vendor_count_maxima_chain_1}")

# Exibir número de observações após filtro percent_chain = 1
print(f"\nNúmero de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_1)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Caracterizar vendor_count dos consumidores com percent_chain >= 0.5
vendor_count_media_chain_05 = consumidores_chain_05['vendor_count'].mean()
vendor_count_minima_chain_05 = consumidores_chain_05['vendor_count'].min()
vendor_count_maxima_chain_05 = consumidores_chain_05['vendor_count'].max()
distribuicao_vendor_count_chain_05 = consumidores_chain_05['vendor_count'].value_counts().sort_index()

# Exibir os resultados para percent_chain >= 0.5
print("\nDistribuição de vendor_count para percent_chain >= 0.5:")
print(distribuicao_vendor_count_chain_05)
print(f"\nVendor count médio: {vendor_count_media_chain_05:.2f}")
print(f"Vendor count mínimo: {vendor_count_minima_chain_05}")
print(f"Vendor count máximo: {vendor_count_maxima_chain_05}")

# Exibir número de observações após filtro percent_chain >= 0.5
print(f"\nNúmero de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_05)}")
"""

# %% [markdown]
# ### product_count

# %% [markdown]
# 1__ 14.8%
# 2__ 19.8%
# 3__ 15.7%
# df_filtered (31750 obs)
# Product count médio: 5.69
# Product count mínimo: 0
# Product count máximo: 269
#
# Dos 12778 consumidores que caem no filtro (percent_chain = 1), 75.3%  têm product_count entre 1 a 4
# Product count médio: 3.82
# Product count mínimo: 1
# Product count máximo: 88
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5), 74% têm product_count entre 1 a 6
# Product count médio: 5.78
# Product count mínimo: 1
# Product count máximo: 269

# %%
"""
# Caracterizar o número de produtos (product_count) dos consumidores em df_filtered
product_count_media = df_filtered['product_count'].mean()
product_count_minima = df_filtered['product_count'].min()
product_count_maxima = df_filtered['product_count'].max()
distribuicao_product_count = df_filtered['product_count'].value_counts().sort_index()

# Exibir os resultados gerais
print("Distribuição de product_count:")
print(distribuicao_product_count)

print(f"\nProduct count médio: {product_count_media:.2f}")
print(f"Product count mínimo: {product_count_minima}")
print(f"Product count máximo: {product_count_maxima}")

# Exibir número total de observações em df_filtered
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Caracterizar product_count dos consumidores com percent_chain = 1
product_count_media_chain_1 = consumidores_chain_1['product_count'].mean()
product_count_minima_chain_1 = consumidores_chain_1['product_count'].min()
product_count_maxima_chain_1 = consumidores_chain_1['product_count'].max()
distribuicao_product_count_chain_1 = consumidores_chain_1['product_count'].value_counts().sort_index()

# Exibir os resultados para percent_chain = 1
print("\nDistribuição de product_count para percent_chain = 1:")
print(distribuicao_product_count_chain_1)
print(f"\nProduct count médio: {product_count_media_chain_1:.2f}")
print(f"Product count mínimo: {product_count_minima_chain_1}")
print(f"Product count máximo: {product_count_maxima_chain_1}")

# Exibir número de observações após filtro percent_chain = 1
print(f"\nNúmero de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_1)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Caracterizar product_count dos consumidores com percent_chain >= 0.5
product_count_media_chain_05 = consumidores_chain_05['product_count'].mean()
product_count_minima_chain_05 = consumidores_chain_05['product_count'].min()
product_count_maxima_chain_05 = consumidores_chain_05['product_count'].max()
distribuicao_product_count_chain_05 = consumidores_chain_05['product_count'].value_counts().sort_index()

# Exibir os resultados para percent_chain >= 0.5
print("\nDistribuição de product_count para percent_chain >= 0.5:")
print(distribuicao_product_count_chain_05)
print(f"\nProduct count médio: {product_count_media_chain_05:.2f}")
print(f"Product count mínimo: {product_count_minima_chain_05}")
print(f"Product count máximo: {product_count_maxima_chain_05}")

# Exibir número de observações após filtro percent_chain >= 0.5
print(f"\nNúmero de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_05)}")
"""

# %% [markdown]
# ### first_order

# %% [markdown]
# df_filtered (31750 obs)
# First order médio: 28.41
# First order mínimo: 0.0
# First order máximo: 90.0
# Começa em 0 com 1436 obs e vai diminuido de forma gradual até 90 com 1 obs
#
# Dos 12778 consumidores que caem no filtro (percent_chain = 1)
# First order médio: 31.62
# First order mínimo: 0.0
# First order máximo: 90.0
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5)
# First order médio: 27.30
# First order mínimo: 0.0
# First order máximo: 90.0
#
# | Segmento                                |      [0, 30]     |    [30, 60]     |    [60, 90]     |
# |-----------------------------------------|------------------|----------------|--------------|
# | Consumidores c/ `order_count` > 0        | 62.5         | 24.9           | 11.6         |
# | "  " & `percent_chain` == 1              | 55.3         | 27.7           | 16.6         |
# |"  " &  `percent_chain` >= 0.5            |              | -              | -            |

# %%
"""
# Caracterizar a variável first_order dos consumidores em df_filtered
first_order_media = df_filtered['first_order'].mean()
first_order_minima = df_filtered['first_order'].min()
first_order_maxima = df_filtered['first_order'].max()
distribuicao_first_order = df_filtered['first_order'].value_counts().sort_index()

# Exibir os resultados gerais
print("Distribuição de first_order:")
print(distribuicao_first_order)

print(f"\nFirst order médio: {first_order_media:.2f}")
print(f"First order mínimo: {first_order_minima}")
print(f"First order máximo: {first_order_maxima}")

# Exibir número total de observações em df_filtered
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Caracterizar first_order dos consumidores com percent_chain = 1
first_order_media_chain_1 = consumidores_chain_1['first_order'].mean()
first_order_minima_chain_1 = consumidores_chain_1['first_order'].min()
first_order_maxima_chain_1 = consumidores_chain_1['first_order'].max()
distribuicao_first_order_chain_1 = consumidores_chain_1['first_order'].value_counts().sort_index()

# Exibir os resultados para percent_chain = 1
print("\nDistribuição de first_order para percent_chain = 1:")
print(distribuicao_first_order_chain_1)
print(f"\nFirst order médio: {first_order_media_chain_1:.2f}")
print(f"First order mínimo: {first_order_minima_chain_1}")
print(f"First order máximo: {first_order_maxima_chain_1}")

# Exibir número de observações após filtro percent_chain = 1
print(f"\nNúmero de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_1)}")
"""

# %%
"""# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Caracterizar first_order dos consumidores com percent_chain >= 0.5
first_order_media_chain_05 = consumidores_chain_05['first_order'].mean()
first_order_minima_chain_05 = consumidores_chain_05['first_order'].min()
first_order_maxima_chain_05 = consumidores_chain_05['first_order'].max()
distribuicao_first_order_chain_05 = consumidores_chain_05['first_order'].value_counts().sort_index()

# Exibir os resultados para percent_chain >= 0.5
print("\nDistribuição de first_order para percent_chain >= 0.5:")
print(distribuicao_first_order_chain_05)
print(f"\nFirst order médio: {first_order_media_chain_05:.2f}")
print(f"First order mínimo: {first_order_minima_chain_05}")
print(f"First order máximo: {first_order_maxima_chain_05}")

# Exibir número de observações após filtro percent_chain >= 0.5
print(f"\nNúmero de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_05)}")
"""

# %% [markdown]
# ### last_order

# %% [markdown]
# df_filtered (31750 obs)
# Last order médio: 63.76
# Last order mínimo: 0
# Last order máximo: 90
#
# Dos 12778 consumidores que caem no filtro (percent_chain = 1)
# Last order médio: 58.57
# Last order mínimo: 0
# Last order máximo: 90
#
# Dos 21990 consumidores que caem no filtro (percent_chain >= 0.5)
# Last order médio: 63.72
# Last order mínimo: 0
# Last order máximo: 90

# %%
"""
# Caracterizar a variável last_order dos consumidores em df_filtered
last_order_media = df_filtered['last_order'].mean()
last_order_minima = df_filtered['last_order'].min()
last_order_maxima = df_filtered['last_order'].max()
distribuicao_last_order = df_filtered['last_order'].value_counts().sort_index()

# Exibir os resultados gerais
print("Distribuição de last_order:")
print(distribuicao_last_order)

print(f"\nLast order médio: {last_order_media:.2f}")
print(f"Last order mínimo: {last_order_minima}")
print(f"Last order máximo: {last_order_maxima}")

# Exibir número total de observações em df_filtered
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
import matplotlib.pyplot as plt
# Obter a distribuição de 'last_order'
distribuicao_last_order = df_filtered['last_order'].value_counts().sort_index()

# Visualizar com um gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(distribuicao_last_order.index, distribuicao_last_order.values)
plt.title('Distribuição de last_order')
plt.xlabel('Dias desde o último pedido (last_order)')
plt.ylabel('Número de consumidores')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
"""
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Caracterizar last_order dos consumidores com percent_chain = 1
last_order_media_chain_1 = consumidores_chain_1['last_order'].mean()
last_order_minima_chain_1 = consumidores_chain_1['last_order'].min()
last_order_maxima_chain_1 = consumidores_chain_1['last_order'].max()
distribuicao_last_order_chain_1 = consumidores_chain_1['last_order'].value_counts().sort_index()

# Exibir os resultados para percent_chain = 1
print("\nDistribuição de last_order para percent_chain = 1:")
print(distribuicao_last_order_chain_1)
print(f"\nLast order médio: {last_order_media_chain_1:.2f}")
print(f"Last order mínimo: {last_order_minima_chain_1}")
print(f"Last order máximo: {last_order_maxima_chain_1}")

# Exibir número de observações após filtro percent_chain = 1
print(f"\nNúmero de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_1)}")
"""

# %%
import matplotlib.pyplot as plt
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Obter a distribuição de 'last_order' para percent_chain = 1
distribuicao_last_order_chain_1 = consumidores_chain_1['last_order'].value_counts().sort_index()

# Criar gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(distribuicao_last_order_chain_1.index, distribuicao_last_order_chain_1.values, color='blue')
plt.title('Distribuição de Last Order para Percent Chain = 1')
plt.xlabel('Dias desde o último pedido (Last Order)')
plt.ylabel('Número de Consumidores')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
"""# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Caracterizar last_order dos consumidores com percent_chain >= 0.5
last_order_media_chain_05 = consumidores_chain_05['last_order'].mean()
last_order_minima_chain_05 = consumidores_chain_05['last_order'].min()
last_order_maxima_chain_05 = consumidores_chain_05['last_order'].max()
distribuicao_last_order_chain_05 = consumidores_chain_05['last_order'].value_counts().sort_index()

# Exibir os resultados para percent_chain >= 0.5
print("\nDistribuição de last_order para percent_chain >= 0.5:")
print(distribuicao_last_order_chain_05)
print(f"\nLast order médio: {last_order_media_chain_05:.2f}")
print(f"Last order mínimo: {last_order_minima_chain_05}")
print(f"Last order máximo: {last_order_maxima_chain_05}")

# Exibir número de observações após filtro percent_chain >= 0.5
print(f"\nNúmero de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {len(df_filtered) - len(consumidores_chain_05)}")
"""

# %% [markdown]
# ### last_promo

# %% [markdown]
# df_filtered (31750 obs)
# Distribuição por promoções:
#  --         52.6%
# DELIVERY    19.7%
# DISCOUNT    14.1%
# FREEBIE     13.7%
#
# Distribuição por últimas promoções (percent_chain = 1):
# --          46.5%
# DELIVERY    24.1%
# DISCOUNT    16%
# FREEBIE     13.4%
#
# Distribuição por promoções (percent_chain >= 0.5):
# --          51.2%
# DELIVERY    19.9%
# DISCOUNT    14.5%
# FREEBIE     13.7%

# %%
"""
# Caracterizar a distribuição dos consumidores em df_filtered por last_promo
distribuicao_promo = df_filtered['last_promo'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição por promoções:")
print(distribuicao_promo)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_1 = len(df_filtered) - len(consumidores_chain_1)

# Caracterizar a distribuição dos consumidores com percent_chain = 1 por customer_region
distribuicao_promo_chain_1 = consumidores_chain_1['last_promo'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por últimas promoções (percent_chain = 1):")
print(distribuicao_promo_chain_1)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_1}")
"""

# %%
"""# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_05 = len(df_filtered) - len(consumidores_chain_05)

# Caracterizar a distribuição dos consumidores com percent_chain >= 0.5 por last_promo
distribuicao_promo_chain_05 = consumidores_chain_05['last_promo'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por promoções (percent_chain >= 0.5):")
print(distribuicao_promo_chain_05)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_05}")
"""

# %% [markdown]
# ### payment_method

# %% [markdown]
# df_filtered (31750 obs)
# Distribuição por forma de pagamento:
# CARD       63.3%
# CASH       17.6%
# DIGI       19.1%
#
# Distribuição por método de pagamento (percent_chain = 1):
# CARD       57.5%
# CASH       21.8%
# DIGI       20.7%
#
# Distribuição por método de pagamento (percent_chain >= 0.5):
# CARD       63.1%
# CASH       17.9%
# DIGI       18.9%

# %%
"""
# Caracterizar a distribuição dos consumidores em df_filtered por payment_method
distribuicao_pay = df_filtered['payment_method'].value_counts().sort_index()

# Exibir os resultados
print("Distribuição por método de pagamento:")
print(distribuicao_pay)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
"""

# %%
"""
# Filtrar consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_1 = len(df_filtered) - len(consumidores_chain_1)

# Caracterizar a distribuição dos consumidores com percent_chain = 1 por payment_method
distribuicao_pay_chain_1 = consumidores_chain_1['payment_method'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por última forma de pagamento (percent_chain = 1):")
print(distribuicao_pay_chain_1)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain = 1): {len(consumidores_chain_1)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_1}")
"""

# %%
"""# Filtrar consumidores com percent_chain >= 0.5
consumidores_chain_05 = df_filtered[df_filtered['percent_chain'] >= 0.5]

# Calcular quantas observações foram filtradas
observacoes_filtradas_chain_05 = len(df_filtered) - len(consumidores_chain_05)

# Caracterizar a distribuição dos consumidores com percent_chain >= 0.5 por last_promo
distribuicao_pay_chain_05 = consumidores_chain_05['payment_method'].value_counts().sort_index()

# Exibir os resultados
print("\nDistribuição por últimas formas de pagamento (percent_chain >= 0.5):")
print(distribuicao_pay_chain_05)

# Exibir número total de observações
print(f"\nNúmero total de observações em df_filtered: {len(df_filtered)}")
print(f"Número de observações após filtro (percent_chain >= 0.5): {len(consumidores_chain_05)}")
print(f"Número de observações filtradas: {observacoes_filtradas_chain_05}")
"""

# %% [markdown]
# ### CIU...

# %% [markdown]
# df_filtered (31750 obs)
# Distribuição por tipo de cozinha:
# CUI_Asian    26%
# CUI_American 12.7%
# CUI_Street Food / Snacks  10.2%
# CUI_Italian   8.4%
# CUI_OTHER     7.8%
# CUI_Japanese   7.8%
# CUI_Beverages   6%
# CUI_Indian      4.3%
# CUI_Chinese     3.7%
# CUI_Healthy     2.5%
# CUI_Desserts    2.3%
# CUI_Thai        2.2%
# CUI_Cafe        2.1%
# CUI_Chicken Dishes  2%
# CUI_Noodle Dishes 1.9%
#
# Distribuição por método de pagamento (percent_chain = 1):
# 1 CUI_Asian    17.7%
# 2 CUI_American 16.3%
# 6 CUI_Street Food / Snacks  6.8%
# 10 CUI_Italian   4%
# 4 CUI_OTHER     9.8%
# 5 CUI_Japanese  9%
# 3 CUI_Beverages 11 %
# 11 CUI_Indian      3.7%
# 7 CUI_Chinese      4.5%
# 12 CUI_Healthy      2.4%
# 14 CUI_Desserts     2.2%
# 13 CUI_Thai        2.5%
# 15 CUI_Cafe        1.9%
# 8 CUI_Chicken Dishes  4.3%
# 9 CUI_Noodle Dishes 4.1%
#
# Distribuição por método de pagamento (percent_chain >= 0.5):
# 1 CUI_Asian    22.4%
# 2 CUI_American 14.9%
# 5 CUI_Street Food / Snacks  8.1%
# 7 CUI_Italian   5.2%
# 3 CUI_OTHER     9.1%
# 4 CUI_Japanese  8.3%
# 6 CUI_Beverages   7.9%
# 9 CUI_Indian      4%
# 8 CUI_Chinese    4.3%
# 12 CUI_Healthy     2.7%
# 15 CUI_Desserts    2.3%
# 14 CUI_Thai        2.4%
# 13 CUI_Cafe          2.7%
# 10 CUI_Chicken Dishes 3%
# 11 CUI_Noodle Dishes 2.8%

# %%
"""# Criar uma função para calcular os gastos por tipo de culinária
def calcular_gastos_culinaria(df, label):
    # Calcular o total gasto por cada tipo de culinária
    gastos = df[culinarias].sum()
    # Criar um DataFrame para os resultados
    gastos_df = pd.DataFrame(gastos).reset_index()
    gastos_df.columns = ['Tipo de Culinária', 'Total Gasto']
    
    # Ordenar os resultados em ordem decrescente
    gastos_df = gastos_df.sort_values(by='Total Gasto', ascending=False)
    
    # Exibir resultados
    print(f"\nGastos por tipo de culinária para {label}:")
    print(gastos_df)

# Análise para consumidores em df_filtered
calcular_gastos_culinaria(df_filtered, "todos os consumidores")

# Análise para consumidores com percent_chain = 1
consumidores_chain_1 = df_filtered[df_filtered['percent_chain'] == 1]
calcular_gastos_culinaria(consumidores_chain_1, "consumidores com percent_chain = 1")

# Análise para consumidores com percent_chain >= 0.5
consumidores_chain_maior_0_5 = df_filtered[df_filtered['percent_chain'] >= 0.5]
calcular_gastos_culinaria(consumidores_chain_maior_0_5, "consumidores com percent_chain >= 0.5")
"""

# %% [markdown]
# !!!! criar uma var que fixa o nome da comida em que gastou mais dinheiro

# %% [markdown]
# ### HR...

# %% [markdown]
# A hora mais comum para os consumidores com filtro order_count' > 0 fazerem pedidos é: HR_17 com um total de 12467 pedidos
# A hora mais comum para os consumidores com filtro  order_count' > 0 e percent_chain = 1 fazerem pedidos é: HR_11 com um total de 3778 pedidos
# A hora mais comum para os consumidores com filtro  order_count' > 0 e percent_chain >= 0.5 fazerem pedidos é: HR_11 com um total de 9191 pedidos

# %%
# Função para analisar as horas mais comuns de pedidos
def analisar_horas_comuns(df, descricao):
    # Somar os pedidos por hora
    horas = [f'HR_{i}' for i in range(24)]
    total_horas = df[horas].sum()
    
    # Encontrar a hora mais comum
    hora_max = total_horas.idxmax()
    valor_max_hora = total_horas.max()

    # Exibir resultados
    print(f"\nAnálise das horas de pedidos para {descricao}:")
    print(total_horas)
    print(f"A hora mais comum para fazer pedidos é: {hora_max} com um total de {valor_max_hora:.0f} pedidos")

# Analisar horas para todos os consumidores
analisar_horas_comuns(df_filtered, "todos os consumidores")

# Analisar horas para consumidores com percent_chain = 1
analisar_horas_comuns(consumidores_chain_1, "consumidores com percent_chain = 1")

# Analisar horas para consumidores com percent_chain >= 0.5
analisar_horas_comuns(consumidores_chain_05, "consumidores com percent_chain >= 0.5")
# Out:
# Análise das horas de pedidos para todos os consumidores:
# HR_0         0.0
# HR_1      1717.0
# HR_2      2015.0
# HR_3      3787.0
# HR_4      3243.0
# HR_5      2613.0
# HR_6      2222.0
# HR_7      2449.0
# HR_8      4206.0
# HR_9      7459.0
# HR_10    10509.0
# HR_11    12059.0
# HR_12    10018.0
# HR_13     7540.0
# HR_14     6876.0
# HR_15     8834.0
# HR_16    11366.0
# HR_17    12467.0
# HR_18    10745.0
# HR_19     7832.0
# HR_20     4554.0
# HR_21     2269.0
# HR_22     1539.0
# HR_23     1441.0
# dtype: float64
# A hora mais comum para fazer pedidos é: HR_17 com um total de 12467 pedidos
#
# Análise das horas de pedidos para consumidores com percent_chain = 1:
# HR_0        0.0
# HR_1      324.0
# HR_2      325.0
# HR_3      707.0
# HR_4      567.0
# HR_5      500.0
# HR_6      456.0
# HR_7      517.0
# HR_8      985.0
# HR_9     1658.0
# HR_10    2408.0
# HR_11    3778.0
# HR_12    3347.0
# HR_13    2534.0
# HR_14    1883.0
# HR_15    2201.0
# HR_16    2651.0
# ...

# %% [markdown]
# De notar que somam as os pedidos das horas todas e dão a resposta, ou seja, não vão pessoa a pessoa ver a que hora ela fez mais pedidos (é outra possível análise)

# %% [markdown]
# ### DOW...

# %% [markdown]
# O dia mais comum para os consumidores com filtro order_count' > 0 fazerem pedidos é: DOW_6 com um total de 22457 pedidos
# O dia mais comum para os consumidores com filtro  order_count' > 0 e percent_chain = 1 fazerem pedidos é: DOW_6 com um total de 6534 pedidos
# O dia mais comum para os consumidores com filtro  order_count' > 0 e percent_chain >= 0.5 fazerem pedidos é: DOW_6 com um total de 16007 pedidos
# Nada a destacar a ordem é sempre 6, 4, 5, 3, 2, 1, 0)

# %%
"""
# Função para analisar os dias da semana mais comuns de pedidos
def analisar_dias_comuns(df, descricao):
    # Somar os pedidos por dia da semana
    dias = [f'DOW_{i}' for i in range(7)]
    total_dias = df[dias].sum()
    
    # Encontrar o dia mais comum
    dia_max = total_dias.idxmax()
    valor_max_dia = total_dias.max()

    # Exibir resultados
    print(f"\nAnálise dos dias de pedidos para {descricao}:")
    print(total_dias)
    print(f"O dia mais comum para fazer pedidos é: {dia_max} com um total de {valor_max_dia:.0f} pedidos")

# Analisar dias para todos os consumidores
analisar_dias_comuns(df_filtered, "todos os consumidores")

# Analisar dias para consumidores com percent_chain = 1
analisar_dias_comuns(consumidores_chain_1, "consumidores com percent_chain = 1")

# Analisar dias para consumidores com percent_chain >= 0.5
analisar_dias_comuns(consumidores_chain_05, "consumidores com percent_chain >= 0.5")
"""

# %% [markdown]
# 3. O output representa o percentual de pedidos feitos em restaurantes "chains" (redes de restaurantes) em cada hora do dia. Aqui está como interpretar os números:
#
# HR_X: Cada linha corresponde a uma hora do dia. Por exemplo, HR_0 é meia-noite, HR_1 é 1 da manhã, e assim por diante até HR_23, que é 11 da noite.
#
# Percentual: O valor ao lado de cada hora representa a porcentagem de todos os pedidos feitos naquela hora que foram em restaurantes chains.
#
# Principais interpretações:
# NaN para HR_0: Significa que não há dados ou pedidos feitos em chains à meia-noite (HR_0). Isso pode ser porque não houve pedidos a essa hora ou porque o cálculo não retornou um valor válido.
#
# Picos de pedidos em chains: As horas com os maiores percentuais de pedidos feitos em chains são:
#
# HR_19 (7 da noite): 76.16%
# HR_20 (8 da noite): 79.11%
# HR_21 (9 da noite): 76.21%
# Isso sugere que, entre 7 e 9 da noite, uma grande parte dos pedidos é feita em redes de restaurantes.
#
# Menores percentuais: As horas mais baixas (com exceção de HR_0, que tem NaN) estão nas primeiras horas da manhã:
#
# HR_3 (3 da manhã): 52.57%
# HR_4 (4 da manhã): 53.48%
# Ou seja, nas primeiras horas da manhã, menos pedidos são feitos em chains em comparação com o horário de jantar.
#
# Conclusão geral:
# Durante o horário de pico das refeições (principalmente o jantar), uma maior porcentagem de pedidos é feita em redes de restaurantes. Já durante as primeiras horas da manhã, embora ainda haja uma presença significativa de pedidos em chains, ela é relativamente menor.

# %% [markdown]
# 6. Análise de clientes extremos
# Identifique os top 10 clientes com o maior número de pedidos em "chains" e veja se há um comportamento específico para esses clientes. Esses insights podem ser úteis para segmentar os clientes heavy-users de redes.
#
# 7. Razão de pedidos em chains versus independentes
# Se houver outra variável que indique o número de pedidos feitos em restaurantes independentes, você poderia calcular a proporção entre pedidos em "chains" e independentes para cada cliente. Isso pode fornecer uma visão mais rica sobre a preferência de redes versus restaurantes locais.
# Análise por Região (customer_region)
# Análise por Idade (customer_age)
#
# A variável is_chain pode ser explorada de diversas maneiras, principalmente para entender como os clientes interagem com restaurantes de redes (chains) em comparação com restaurantes independentes. Aqui estão algumas análises adicionais que podem ser feitas para aprofundar as informações já obtidas:
#
# 8. Comportamento de Compra ao Longo do Tempo (acho que não é possível)
# Evolução dos Pedidos em Chains ao Longo dos Meses: Analisar se há uma tendência crescente ou decrescente de pedidos em chains ao longo dos três meses. Isso pode revelar mudanças sazonais ou de comportamento.
# Intervalo entre Pedidos e Chains: Analisar o intervalo entre pedidos sucessivos de clientes que preferem chains em comparação com aqueles que preferem não-chains.
#
# 3. Análise de Preferência por Tipo de Culinária
# Já vimos o gasto médio em diferentes tipos de culinária, mas podemos segmentar mais profundamente:
# Comparar o número total de pedidos de cada tipo de culinária (e não apenas o gasto) entre chains e não-chains.
# Analisar categorias específicas: Por exemplo, você mencionou um comportamento interessante em CUI_Chicken Dishes. Pode ser útil verificar a frequência com que pedidos de chicken dishes são feitos em chains, já que isso pode sugerir a dominância desse tipo de prato em redes de fast food.
#
# 4. Análise por Dia e Hora (Padrões Temporais)
# Distribuição dos Pedidos por Dia da Semana: Verificar como a escolha por chains versus não-chains varia ao longo dos dias da semana. Já temos correlações, mas uma análise visual ou categórica (como percentuais de pedidos por dia) pode mostrar padrões mais claros.
# Padrões Diários Específicos: Já vimos que as horas de jantar têm uma alta prevalência de pedidos em chains. Uma análise mais detalhada pode incluir a criação de categorias temporais, como “almoço”, “jantar”, e “madrugada”, para ver quais horários do dia mais influenciam a preferência por redes.
#
# 5. Análise de Promoções
# Uso de Promoções e Preferência por Chains: Analisar se os clientes que utilizam promoções são mais propensos a fazer pedidos em chains. A variável last_promo pode ser cruzada com is_chain para verificar se redes de restaurantes são mais agressivas em oferecer descontos.
# Promoção por Categoria de Produto: Identificar se as promoções são mais comuns em certos tipos de culinária e se isso afeta a escolha por chains.
#
# 6. Fidelidade e Frequência de Pedidos
# Clientes que preferem Chains versus Frequência de Pedidos: Verificar se clientes que preferem chains fazem pedidos com mais frequência ou se os clientes que preferem não-chains têm uma frequência mais alta de pedidos.
# Clientes Fieis a Chains Específicas: Se houver dados adicionais sobre os fornecedores, pode-se explorar se certos clientes pedem repetidamente de uma mesma chain, indicando um comportamento de fidelidade.
#
# 7. Análise por Método de Pagamento
# Método de Pagamento e Chains: Explorar se os clientes que preferem chains tendem a usar certos métodos de pagamento mais frequentemente do que outros. Isso pode ajudar a identificar tendências em como os consumidores preferem pagar em restaurantes de rede (por exemplo, maior uso de aplicativos ou cartões de crédito).
#
# 8. Comparação com Variáveis Financeiras
# Gasto Total: Comparar o gasto total de clientes que preferem chains com os que preferem não-chains. Isso pode ajudar a determinar se os clientes de redes gastam mais ou menos, em média.
# Valor Médio por Pedido em Chains versus Não-Chains: Calcular o valor médio gasto por pedido em restaurantes chains e não-chains para ver se há uma diferença significativa.
# Essas análises adicionais podem fornecer insights mais profundos sobre os hábitos dos clientes em relação a redes de restaurantes e como esses comportamentos são influenciados por outros fatores (como horário, tipo de culinária, promoções, etc.).

# %% [markdown]
# ## last_promo

# %%
#1.
#Unique values e freq absoluta
unique_values = df['first_order'].value_counts()
print("Frequências absolutas:")
print(unique_values)

#moda
moda_value = df['first_order'].mode()[0]
print(f"Moda: {moda_value}")

#var e std
variancia = df['first_order'].var()
desvio_padrao = df['first_order'].std()
print(f"Variância: {variancia}")
print(f"Desvio padrão: {desvio_padrao}")

#assimetria e Curtose
assimetria = df['first_order'].skew()
curtose = df['first_order'].kurt()
print(f"Assimetria: {assimetria}")
print(f"Curtose: {curtose}")

# Freq relativa
relative_values = df['first_order'].value_counts(normalize=True)
print("\nFrequências relativas (%):")
print(relative_values * 100)

#Haverá outliers?
print("\nResumo estatístico da variável 'first_order':")
print(df['first_order'].describe())

#Média e mediana
mean_value = df['first_order'].mean()
median_value = df['first_order'].median()
print(f"\nMédia: {mean_value}")
print(f"Mediana: {median_value}")
